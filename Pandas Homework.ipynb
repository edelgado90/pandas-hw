# %%
import pandas as pd
import numpy as np

# %%
file_one = os.path.join("purchase_data_3.csv")
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
total_players = {'Total Players':[1]}
total_players_df = pd.DataFrame(data=total_players)
total_players_df['Total Players']= file_one_df["SN"].nunique()
total_players_df.head()
# Out:
#    Total Players
# 0             74

# %%
purchases ={'Number of Unique Items':[1],
            "Average Price":[1],
            "Number of Purchases":[1],
            "Total Revenue":[1]}

purchases_df = pd.DataFrame(data=purchases)

purchases_df["Number of Unique Items"] = file_one_df["Item ID"].nunique()

purchases_df["Average Price"] = file_one_df["Price"].mean()

purchases_df["Number of Purchases"] = file_one_df["Purchase ID"].count()

purchases_df["Total Revenue"] = file_one_df["Price"].sum()

purchases_df
# Out:
#    Average Price  Number of Purchases  Number of Unique Items  Total Revenue
# 0       2.924359                   78                      64          228.1

# %%
gender_counts_df = pd.DataFrame(file_one_df["Gender"].value_counts())

gender_counts_df["Percentage of Players"] = gender_counts_df["Gender"] / gender_counts_df["Gender"].sum()

gender_counts_df.rename(columns={'Gender':'Total Count'}, inplace=True)

gender_counts_df["Percentage of Players"] = gender_counts_df["Percentage of Players"].map("{:.0%}".format)  

gender_counts_df
# Out:
#                        Total Count Percentage of Players
# Male                            64                   82%
# Female                          13                   17%
# Other / Non-Disclosed            1                    1%

# %%
gender_purchase_df = pd.DataFrame(file_one_df.groupby(['Gender']).count()["Purchase ID"])

gender_purchase_df = gender_purchase_df.rename(columns={'Purchase ID': 'Purchase Count'})

gender_purchase_df["Average Purchase Price"] = file_one_df.groupby(['Gender']).mean()["Price"]

gender_purchase_df["Total Purchase Value"] = file_one_df.groupby(['Gender']).sum()["Price"]

gender_purchase_df["Normalized Total"] = file_one_df.groupby(['Gender']).sum()["Price"] / file_one_df.sum()["Price"]

gender_purchase_df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                             13                3.183077
# Male                               64                2.884375
# Other / Non-Disclosed               1                2.120000
#
#                        Total Purchase Value  Normalized Total
# Gender
# Female                                41.38          0.181412
# Male                                 184.60          0.809294
# Other / Non-Disclosed                  2.12          0.009294

# %%
product_df = pd.DataFrame(file_one_df.groupby(['Item Name']).sum()['Price'])

# %%
product_df_sorted = product_df.sort_values("Price", ascending=False)

top_product_df = product_df_sorted.iloc[0:5,]

top_product_df.reset_index()

#df.index = range(len(df.index))

top_product_df.index = range(len(top_product_df.index))


#file_one_df[""]

#product_df = file_one_df.copy()

#product_df["Total Sales"] = product_df.groupby(['Item Name']).sum()['Price']


#product_df_sorted = product_df.sort_values("Price", ascending=False)

#product_matrix_df = file_one_df.loc[
#freedom_df = happiness_df.sort_values("Freedom", ascending=False)


top_product_df
# Out:
#    Price
# 0  10.92
# 1   9.42
# 2   8.98
# 3   8.24
# 4   8.22

# %%
bins = [0, 10, 15, 20, 40]

group_names = ['<10', '10-15', '16-20', '21-40']

age_df = file_one_df.copy()

age_df["Age Group"] = pd.cut(age_df["Age"], bins, labels=group_names)

age_purchase_df = pd.DataFrame(age_df.groupby(["Age Group"]).count()["Purchase ID"])

age_purchase_df = age_purchase_df.rename(columns={'Purchase ID': 'Purchase Count'})

age_purchase_df["Average Purchase Price"] = age_df.groupby("Age Group").mean()["Price"]

age_purchase_df["Total Purchase Value"] = age_df.groupby(["Age Group"]).sum()["Price"]

age_purchase_df["Normalized Total"] = age_df.groupby(["Age Group"]).sum()["Price"] / age_df.sum()["Price"]

age_purchase_df
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Group
# <10                     5                2.764000                 13.82
# 10-15                   4                3.052500                 12.21
# 16-20                  20                2.734500                 54.69
# 21-40                  49                3.007755                147.38
#
#            Normalized Total
# Age Group
# <10                0.060587
# 10-15              0.053529
# 16-20              0.239763
# 21-40              0.646120

# %%
top_spender_df = file_one_df.copy()
top_spender_df.head()

top_spender_df["Total Purchase Value"] = top_spender_df.groupby(['SN']).sum()["Price"]

top_spender_df
# Out:
#     Purchase ID             SN  Age                 Gender  Item ID  \
# 0             0        Iloni35   20                   Male       93
# 1             1      Aidaira26   21                   Male       12
# 2             2         Irim47   17                   Male        5
# 3             3        Irith83   17                   Male      123
# 4             4     Philodil43   22                   Male      154
# 5             5     Hainaria90    8                   Male        8
# 6             6  Aerithllora36   40                   Male      148
# 7             7      Undirra90   28                   Male       27
# 8             8      Eolideu96   18                   Male      111
# 9             9  Aesurstilis64   36                   Male      139
# 10           10    Jiskimsda56   24                   Male      126
# 11           11       Jiskim75   36                 Female      173
# 12           12     Lirtassa77   20                 Female       90
# ...

# %%
top_spender_df.dtypes
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# dtype: object

# %%
#grouped_top_spender_df["Total Spend"] = top_spender_df.groupby(["SN"]).sum()["Price"]

#astype(dtype, copy=True, errors='raise', **kwargs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-212-7cee654ba900> in <module>()
# ----> 1 grouped_top_spender_df["Total Spend"] = top_spender_df.groupby(["SN"]).sum()["Price"]
#       2
#       3 #astype(dtype, copy=True, errors='raise', **kwargs)
#
# TypeError: 'DataFrameGroupBy' object does not support item assignment

# %%
#top_spender_df["Total Spend"] = top_spender_df.groupby(["Item"]).sum()["Price"]

# %%
file_one = os.path.join("purchase_data_3.csv")
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")
grouped_top_spender_df.head()
# Out:
#     Purchase ID             SN  Age                 Gender  Item ID  \
# 0             0        Iloni35   20                   Male       93
# 1             1      Aidaira26   21                   Male       12
# 2             2         Irim47   17                   Male        5
# 3             3        Irith83   17                   Male      123
# 4             4     Philodil43   22                   Male      154
# 5             5     Hainaria90    8                   Male        8
# 6             6  Aerithllora36   40                   Male      148
# 7             7      Undirra90   28                   Male       27
# 8             8      Eolideu96   18                   Male      111
# 9             9  Aesurstilis64   36                   Male      139
# 10           10    Jiskimsda56   24                   Male      126
# 11           11       Jiskim75   36                 Female      173
# 12           12     Lirtassa77   20                 Female       90
# ...

# %%
new_file = os.path.join("purchase_data_3.csv")
mew_file_df = pd.read_csv(new_file, encoding="ISO-8859-1")

# %%
mew_file_df.dtypes
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# Total Value     object
# dtype: object

# %%
mew_file_df['Total Value'] = mew_file_df.sum()
mew_file_df
# Out:
#     Purchase ID             SN  Age                 Gender  Item ID  \
# 0             0        Iloni35   20                   Male       93
# 1             1      Aidaira26   21                   Male       12
# 2             2         Irim47   17                   Male        5
# 3             3        Irith83   17                   Male      123
# 4             4     Philodil43   22                   Male      154
# 5             5     Hainaria90    8                   Male        8
# 6             6  Aerithllora36   40                   Male      148
# 7             7      Undirra90   28                   Male       27
# 8             8      Eolideu96   18                   Male      111
# 9             9  Aesurstilis64   36                   Male      139
# 10           10    Jiskimsda56   24                   Male      126
# 11           11       Jiskim75   36                 Female      173
# 12           12     Lirtassa77   20                 Female       90
# ...

# %%
testing_df = file_one_df.copy()

# %%
#data.groupby('month', as_index=False).agg({"duration": "sum"})

testing_df = testing_df.groupby('Item Name', as_index=False).agg({"Price": "sum"})

testing_df = testing_df.sort_values("Price", ascending=False).reset_index()

testing_df

top_5_df = testing_df.iloc[0:5,]

top_5_df

top_5_list = top_5_df["Item Name"].tolist()

top_5_list
# Out:
# ['Mourning Blade',
#  'Heartstriker, Legacy of the Light',
#  'Apocalyptic Battlescythe',
#  'Betrayer',
#  'Feral Katana']

# %%
tester_df = file_one_df.copy()

tester_df = tester_df.reset_index()

tester_df
# Out:
#     index  Purchase ID             SN  Age                 Gender  Item ID  \
# 0       0            0        Iloni35   20                   Male       93
# 1       1            1      Aidaira26   21                   Male       12
# 2       2            2         Irim47   17                   Male        5
# 3       3            3        Irith83   17                   Male      123
# 4       4            4     Philodil43   22                   Male      154
# 5       5            5     Hainaria90    8                   Male        8
# 6       6            6  Aerithllora36   40                   Male      148
# 7       7            7      Undirra90   28                   Male       27
# 8       8            8      Eolideu96   18                   Male      111
# 9       9            9  Aesurstilis64   36                   Male      139
# 10     10           10    Jiskimsda56   24                   Male      126
# ...

# %%
results_df = pd.DataFrame(columns= ['Item ID','Item Name'],
                         index= top_5_list)



#for x in top_5_list:
    #results_df.loc[x,'Item ID']= tester_df.groupby(['Item Name']).loc[x,'Item ID']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-320-72372b21dd80> in <module>()
#       3
#       4 for x in top_5_list:
# ----> 5     results_df.loc[x,'Item ID']= tester_df.groupby(['Item Name']).loc[x,'Item ID']
#       6
#       7
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     671             return self[attr]
#     672         if hasattr(self.obj, attr):
# --> 673             return self._make_wrapper(attr)
#     674
#     675         raise AttributeError("%r object has no attribute %r" %
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/groupby.py in _make_wrapper(self, name)
#     685                    "using the 'apply' method".format(kind, name,
#     686                                                      type(self).__name__))
# ...
